# %%
import SimPEG.Utils as Utils
from em_examples.DC_cylinder import *
# %matplotlib inline

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x109c25a90>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x109c11a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110101810>], dtype=object))
