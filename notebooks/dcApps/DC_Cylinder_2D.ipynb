# %%
import sys
pathName = '../../em_examples/'
sys.path.append(pathName)
# from DCLayers import *
import SimPEG.Utils as Utils
from DC_cylinder import *
# %matplotlib inline

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x11d648710>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d636a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122805d90>], dtype=object))
