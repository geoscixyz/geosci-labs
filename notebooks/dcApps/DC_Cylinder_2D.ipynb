# %%
import sys
pathName = '../../em_examples/'
sys.path.append(pathName)
import SimPEG.Utils as Utils
from DC_cylinder import *
# %matplotlib inline
# Out:
# Efficiency Warning: Interpolation will be slow, use setup.py!
#
#             python setup.py build_ext --inplace

# %%
plot_Profile(A=-30.25,B=30.25,r=10.,rhocyl=10.,rhohalf=100.,xc=0.,yc=-15,rx_nc=2.)
# Out:
# (<matplotlib.figure.Figure at 0x103669d50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x10dbd7550>)

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x10bfa1950>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x10dbf6f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c5fdad0>], dtype=object))

# %%
mesh.vectorCCy
# Out:
# array([ -2.46250000e+04,  -1.23370000e+04,  -6.19300000e+03,
#         -3.12100000e+03,  -1.58500000e+03,  -8.17000000e+02,
#         -4.33000000e+02,  -2.41000000e+02,  -1.45000000e+02,
#         -9.70000000e+01,  -7.30000000e+01,  -6.10000000e+01,
#         -5.50000000e+01,  -5.20000000e+01,  -5.05000000e+01,
#         -4.97500000e+01,  -4.92500000e+01,  -4.87500000e+01,
#         -4.82500000e+01,  -4.77500000e+01,  -4.72500000e+01,
#         -4.67500000e+01,  -4.62500000e+01,  -4.57500000e+01,
#         -4.52500000e+01,  -4.47500000e+01,  -4.42500000e+01,
#         -4.37500000e+01,  -4.32500000e+01,  -4.27500000e+01,
#         -4.22500000e+01,  -4.17500000e+01,  -4.12500000e+01,
#         -4.07500000e+01,  -4.02500000e+01,  -3.97500000e+01,
#         -3.92500000e+01,  -3.87500000e+01,  -3.82500000e+01,
#         -3.77500000e+01,  -3.72500000e+01,  -3.67500000e+01,
#         -3.62500000e+01,  -3.57500000e+01,  -3.52500000e+01,
# ...

# %%
n = 5.

# %%
M = np.c_[np.arange(-30.25+n*cs,30.25-n*cs,n*cs),np.ones(np.arange(-30.25+n*cs,30.25-n*cs,n*cs).shape)]

# %%
N = np.arange(-30.25+2*n*cs,30.25,n*cs)

# %%
np.arange(-30.25+n*cs,30.25-n*cs,n*cs).shape
# Out:
# (23,)

# %%
M
# Out:
# array([[-27.75,   1.  ],
#        [-25.25,   1.  ],
#        [-22.75,   1.  ],
#        [-20.25,   1.  ],
#        [-17.75,   1.  ],
#        [-15.25,   1.  ],
#        [-12.75,   1.  ],
#        [-10.25,   1.  ],
#        [ -7.75,   1.  ],
#        [ -5.25,   1.  ],
#        [ -2.75,   1.  ],
#        [ -0.25,   1.  ],
#        [  2.25,   1.  ],
#        [  4.75,   1.  ],
#        [  7.25,   1.  ],
#        [  9.75,   1.  ],
#        [ 12.25,   1.  ],
#        [ 14.75,   1.  ],
#        [ 17.25,   1.  ],
#        [ 19.75,   1.  ],
#        [ 22.25,   1.  ],
#        [ 24.75,   1.  ],
#        [ 27.25,   1.  ]])

# %%
M-N
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d1b81c0cc14b> in <module>()
# ----> 1 M-N
#
# ValueError: operands could not be broadcast together with shapes (23,2) (23,)

# %%
(M+N)/2.
