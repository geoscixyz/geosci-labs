# %%
import sys
pathName = '../../em_examples/'
sys.path.append(pathName)
import SimPEG.Utils as Utils
from DC_cylinder import *
# %matplotlib inline

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x1165ba810>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x109c77450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a354650>], dtype=object))
