# %%
import sys
pathName = '../../em_examples/'
sys.path.append(pathName)
import SimPEG.Utils as Utils
from DC_cylinder import *
# %matplotlib inline

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x10dd3e6d0>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x10dd3ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f390250>], dtype=object))
