# %%
import sys
pathName = '../../em_examples/'
sys.path.append(pathName)
# from DCLayers import *
import SimPEG.Utils as Utils
from DC_cylinder import *
# %matplotlib inline

# %%
app = cylinder_app()
# Out:
# (<matplotlib.figure.Figure at 0x1279e60d0>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x1279de550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1148d0690>], dtype=object))
