# %%
from em_examples.DCWidgetPlate_2D import plate_app
# %matplotlib inline
# Out:
# Efficiency Warning: Interpolation will be slow, use setup.py!
#
#             python setup.py build_ext --inplace

# %% [markdown]
# # Purpose
#
# For a direct current resistivity (DCR) survey, currents are injected to the earth, and flow.
# Depending upon the conductivity contrast current flow in the earth will be distorted, and these changes
# can be measurable on the sufurface electrodes.
# Here, we focus on a plate target embedded in a halfspace, and investigate what are happening in the earth when static currents are injected. Different from a sphere case, which is symmetric, "coupling" among Tx, target (conductor or resistor), and Rx will be significanlty different upon various scenarios.
# By investigating changes in currents, electric fields, potential, and charges upon different geometry of plate, Tx and Rx location, we understand geometric effects of the target for DCR survey.

# %% [markdown]
# # Set up
#
# XXX

# %% [markdown]
# # Questions

# %% [markdown]
# # Plate app
#
# ## Parameters:

# %% [markdown]
#  - **survey**: Type of survey
#  - **A**: (+) Current electrode  location
#  - **B**: (-) Current electrode  location
#  - **M**: (+) Potential electrode  location
#  - **N**: (-) Potential electrode  location
#  - **dx**: width of plate
#  - **dz**: height/thickness of plate
#  - **xc**: x location of plate center
#  - **zc**: z location of plate center
#  - **$\theta$**: rotation angle of plate from the horizontal
#  - **$\rho_2$**: Resistivity of the plate
#  - **$\rho_1$**: Resistivity of the halfspace
#  - **Field**: Field to visualize
#  - **Type**: which part of the field

# %%
app = plate_app();
app

# %% [markdown]
# # Explore
