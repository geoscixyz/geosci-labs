# %%
# %matplotlib inline
import sys
sys.path.append("../../util_codes/")
from DipoleWidget import DipoleWidget

# %%
DipoleWidget??

# %%
dwidget = DipoleWidget()
dwidget.InteractiveDipole()
# Out:
# True

# %%
import SimPEG
# Out:
# Efficiency Warning: Interpolation will be slow, use setup.py!
#
#             python setup.py build_ext --inplace

# %%
SimPEG.__path__
# Out:
# ['C:\\Users\\tastic\\Documents\\SimPEG\\SimPEG']

# %%
EM.Analytics.E_galvanic_from_ElectricDipoleWholeSpace??
# Out:
# Object `EM.Analytics.E_galvanic_from_ElectricDipoleWholeSpace` not found.
