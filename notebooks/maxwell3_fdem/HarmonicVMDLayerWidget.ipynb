# %%
# %pylab inline
from em_examples.HarmonicVMDCylWidget import HarmonicVMDCylWidget
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Title: Harmonic VMD in Layered Earth

# %% [markdown]
# # Purpose
#
# Harmonic Vertical Magnetic Dipole (VMD) is a magnetic source, which excite the earth with EM induction. Magnetic source is sort of an artifical concept, and a small enough circular loop can be an equivalent. Different from homogenous earth, we often assume the earth is layerd indicating each layer has different electrical properties. For instance, often Tx is deployed in the air (e.g. airborne EM and small-loop EM) having zero conductivity i.e. no conduction currents. This drastic contrast of electrical properties changes reflection and refraction of EM waves effectively distorts EM fields in the earth.

# %%
vmd = HarmonicVMDCylWidget()
Q1 = vmd.InteractivePlane(); Q1

# %%
Q2 = vmd.InteractiveData(); Q2
