# %%
from SimPEG import Mesh, Maps, EM, Utils
import numpy as np
from em_examples.TransientVMDCylWidget import TransientVMDCylWidget
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
vmd = TransientVMDCylWidget()
Q1 = vmd.InteractivePlane(sig0=3.33, sig1=1., sig2=1., sig3=1., radius=1.975, z0=4., x0=0.); Q1

# %%
# temp = -vmd.dBzdt

# %%
# vmd.setThreeLayerParam(sig0=3.33, sig1=1., sig2=1., sig3=1., h1=18, h2=18)
# vmd.simulate(vmd.srcLoc, vmd.rxLoc, vmd.time, radius = 1.975)
# vmd.getData()
# data0 = -vmd.dBzdt
# vmd.setThreeLayerParam(sig0=3.33, sig1=1., sig2=10., sig3=1., h1=18, h2=18)
# vmd.simulate(vmd.srcLoc, vmd.rxLoc, vmd.time, radius = 1.975)
# vmd.getData()
# data1 = -vmd.dBzdt

# %%
# plt.loglog(vmd.prb.times, data0)
# plt.loglog(vmd.prb.times, data1)

# %%
# plt.plot(vmd.prb.times, data1/data0)

# %%
Q2 = vmd.InteractiveData(); Q2
