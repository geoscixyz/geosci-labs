# %%
from MT import *
% matplotlib inline

# %% [markdown]
# # MT: 1 to 3 layers forward Modelling

# %% [markdown]
# Here you can visualize MT response of a layered earth, up to 3 layers in this interactive notebook.
#
# **h** (i): thickness of the layer i. Put it to zero to remove one layer
#
# **sigl**(i): log of the electrical conductivity of the layer i, in S/m (ex: sigl3= -5 means a conductivity of $10^{-5}$ S/m)
#
# **epsl**(i): relative dielectric permittivity $\varepsilon_r$ of the layer i
#
# **mul**(i): relative magnetic permittivity $\mu_r$ of the layer i
#
# **envelope**: (0= False, 1= True), If True (might be slow), plot the envelope of the E and H field for a given frequency (see fenvelope)
#
# **fenvelope**:the "[fenvelope]-th" frequency of the data array

# %%
    interact(PlotAppRes3LayersInteract,h1=FloatSlider(min=0.,max=1000.,step=20.,value=100.),
             h2=FloatSlider(min=0.,max=1000.,step=20.,value=1000.),sigl1=FloatSlider(min=-5.,max=0.,step=0.5,value=-1.),
             sigl2=FloatSlider(min=-5.,max=0.,step=0.5,value=-3)
             ,sigl3=FloatSlider(min=-5.,max=0.,step=0.5,value=-1),mul1=FloatSlider(min=1.,max=1.2,step=0.01,value=1.),
             mul2=FloatSlider(min=1.,max=1.2,step=0.01,value=1.),mul3=FloatSlider(min=1.,max=1.2,step=0.01,value=1.),
             epsl1=FloatSlider(min=1.,max=80.,step=1.,value=1.),epsl2=FloatSlider(min=1.,max=80.,step=1,value=3.)
             ,epsl3=FloatSlider(min=1.,max=80.,step=1.,value=80.),envelope=(0,1,1),fenvelope=IntSlider(min=0,max=99,step=1,value=90))
# Out:
# No envelop (if True, might be slow)
# <function MT.PlotAppRes3LayersInteract>
