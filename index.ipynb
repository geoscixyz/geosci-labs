# %% [markdown]
# <a href="http://em.geosci.xyz"><img src="https://em.geosci.xyz/_images/disc_dipole.png" style="width: 25%; height: 25%" align="right"></img></a>
#
# # EM GeoSci Apps
#
# The purpose of these notebooks is to provide tools for you to investigate fundamental concepts in electromagnetic geophysics. They support **<a href="http://em.geosci.xyz">em.geosci.xyz</a>**, an open source "textbook" resource for electromagnetic geophysics.
#
# These notebooks are powered by <a href="http://simpeg.xzy">SimPEG</a>, an open source framework for Simulation and Parameter Estimation in Geophysics.
#
# If you have feedback, we would like to hear from you!
# - <a href="http://geosci.xyz/contact">Contact us</a>
# - <a href="https://github.com/geoscixyz/em_apps/issues">Report issues</a>
# - <a href="https://github.com/geoscixyz/em_apps/">Join the development</a>

# %% [markdown]
# **[DC](#DC-Resistivity) | [EM Fundamentals](#EM-Fundamentals) | [Inductive Sources](#Inductive-Source-EM) | [Grounded Sources](#Grounded-Source-EM) | [Natural Sources](#Natural-Source-EM) | [IP](#Induced-Polarization) | [Inversion](Inversion)**
#
#
# ## Contents
#
# #### DC Resistivity
# - [DC_LayeredEarth.ipynb](./notebooks/DC_LayeredEarth.ipynb)
# - [DC_Cylinder_2D.ipynb](./notebooks/DC_Cylinder_2D.ipynb)
# - [DC_Building_Pseudosections.ipynb](./notebooks/DC_Building_Pseudosections.ipynb)
# - [DC_Inversions.ipynb](./notebooks/DC_Inversions.ipynb)
# - [DC_Layer_Cylinder_2D.ipynb](./notebooks/DC_Layer_Cylinder_2D.ipynb)
# - [DC_Layer_Cylinder_2_5D.ipynb](./notebooks/DC_Layer_Cylinder_2_5D.ipynb)
# - [DC_Plate_2D.ipynb](./notebooks/DC_Plate_2D.ipynb)
# - [DC_Plate2_5D.ipynb](./notebooks/DC_Plate2_5D.ipynb)
# - [DCIP_2D_Overburden_Pseudosections.ipynb](./notebooks/DCIP_2D_Overburden_Pseudosections.ipynb)
# - [DC_Overburden_2_5D.ipynb](./notebooks/DC_Overburden_2_5D.ipynb)
# - [DC_Sphere_Constant_E.ipynb](./notebooks/DC_Sphere_Constant_E.ipynb)
#
# #### EM Fundamentals
# - [FDEM_ThreeLoopModel.ipynb](./notebooks/FDEM_ThreeLoopModel.ipynb)
# - [InductionRLcircuit_Transient.ipynb](./notebooks/InductionRLcircuit_Transient.ipynb)
# - [InductionRLcircuit_Harmonic.ipynb](./notebooks/InductionRLcircuit_Harmonic.ipynb)
# - [FDEM_Inductive_Sphere.ipynb](./notebooks/FDEM_Inductive_Sphere.ipynb)
# - [TDEM_Planewave_Wholespace.ipynb](./notebooks/TDEM_Planewave_Wholespace.ipynb)
# - [FDEM_Planewave_Wholespace.ipynb](./notebooks/FDEM_Planewave_Wholespace.ipynb)
# - [TDEM_MagneticDipole_Wholespace.ipynb](./notebooks/TDEM_MagneticDipole_Wholespace.ipynb)
# - [FDEM_MagneticDipole_Wholespace.ipynb](./notebooks/FDEM_MagneticDipole_Wholespace.ipynb)
#
# #### Inductive Source EM
# - [TDEM_HorizontalLoop_LayeredEarth.ipynb](./notebooks/TDEM_HorizontalLoop_LayeredEarth.ipynb)
# - [TDEM_HorizontalLoop_Sphere.ipynb](./notebooks/TDEM_HorizontalLoop_Sphere.ipynb)
# - [FDEM_VMD_LayeredEarth.ipynb](./notebooks/FDEM_VMD_LayeredEarth.ipynb)
# - [FDEM_VMD_Sphere.ipynb](./notebooks/FDEM_VMD_Sphere.ipynb)
# - [TDEM_Inductivesource.ipynb](./notebooks/TDEM_Inductivesource.ipynb)
# - [TDEM_UXO.ipynb](./notebooks/TDEM_UXO.ipynb)
#
# #### Grounded Source EM
# - [TDEM_ElectricDipole_Wholespace.ipynb](./notebooks/TDEM_ElectricDipole_Wholespace.ipynb)
# - [FDEM_ElectricDipole_Wholespace.ipynb](./notebooks/FDEM_ElectricDipole_Wholespace.ipynb)
# - [MarineCSEM_LayeredEarth.ipynb](./notebooks/MarineCSEM_LayeredEarth.ipynb)
# - [TDEM_Groundedsource.ipynb](./notebooks/TDEM_Groundedsource.ipynb)
#
# #### Natural Source EM
# - [FDEM_Planewave_Reflection.ipynb](./notebooks/FDEM_Planewave_Reflection.ipynb)
# - [MT_LayeredEarth.ipynb](./notebooks/MT_LayeredEarth.ipynb)
#
# #### Induced Polarization
# - [PhyProp_ColeCole.ipynb](./notebooks/PhyProp_ColeCole.ipynb)
#
# #### Inversion
# - [LinearInversion.ipynb](./notebooks/LinearInversion.ipynb)

# %% [markdown]
# ## Running the notebook
#
# From the menu, select `cell`, `run all`, or run each individual cell using `shift + enter`
#
# ![cell-run-all](https://em.geosci.xyz/_images/run_all_cells.png)

# %% [markdown]
# #### <center>We love open source!</center>
#
# <center><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style="border-width:0" width=60 src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a>
#
# This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.</center>
