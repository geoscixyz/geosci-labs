# %%
import sys
sys.path.append("../RefractionSurvey/")
from SeisRefrac import *
# %matplotlib inline

# %%
fig,ax = plt.subplots(figsize=(10,10))
#ax=viewTXdiagram(x0=0.5, dx=5, v1=500., v2=1300., v3=1300., z1=15., z2=25., ax=ax,legend=False)
ax=plotWiggleTX(x0=0.5, dx=5, v1=500., v2=1300., v3=1300., z1=15., z2=25., ax=ax, noise=True)
majorxtick = np.arange(0.,131.,20)
minorxtick = np.arange(0.,131,5.)
majorytick = np.arange(0.,0.26,0.05)
minorytick = np.arange(0.,0.26,0.01)
ax.set_xticks(majorxtick)
ax.set_xticks(minorxtick,minor=True)
ax.set_yticks(majorytick)
ax.set_yticks(minorytick,minor=True)
ax.set_xlim(0., 100.)
ax.set_ylim(0., 0.25)
ax.grid(which='both',axis='both', linestyle='-',linewidth= 1., color='k', alpha=0.3)
ax.invert_yaxis()
ax.tick_params(axis='both', which='major', labelsize=16)
