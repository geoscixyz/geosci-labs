# %%
# %matplotlib inline
import numpy as np
from SeisRefrac import makeinteractTXwigglediagram, makeinteractSeisRefracSruvey, makeinteractTXdiagram
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["font.size"] = 16

# %% [markdown]
# # Suvey design for Seismic Refraction survey

# %% [markdown]
# Consider a shot gather for seismic refraction survey, which means we have one shot (source)

# %%
makeinteractSeisRefracSruvey()
# Out:
# True

# %%
# makeinteractTXdiagram()

# %%
makeinteractTXwigglediagram()
