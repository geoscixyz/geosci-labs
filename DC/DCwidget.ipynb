# %%
from DCWidget import *
# %matplotlib inline
# Out:
# Efficiency Warning: Interpolation will be slow, use setup.py!
#
#             python setup.py build_ext --inplace

# %%
flag = "DipoleDipole"

# %%
dobs, uncert, mesh, survey, mapping, xr, xzlocs = DC2Dsurvey(flag)

# %%
PoleDipoleWidget()
# Out:
# <function DCWidget.DipoleDipolefun>

# %% [markdown]
# Need to be able to make j a funtion of i since not all of the Tx have the same number of measurements. Not sure how to do this.... Certainly closer than it was.

# %%
PseudoSectionWidget(survey,flag)
# Out:
# [[0.0, 0], [5.0, 0]]

# %%
DC2DfwdWidget(mesh, survey, mapping, dobs, uncert, xr, xzlocs)
