# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
from scipy.constants import mu_0, epsilon_0

# %%
import Image
from matplotlib.widgets import Cursor
matplotlib.rcParams.update({'font.size': 16, 'font.family': 'arial'})

# %%
img = Image.open('ubc_GPRdata.png')
imgnew = img.resize((200, 250))

# %%
fig = plt.figure(num=None, figsize=(10,8))
plt.imshow(img, extent = [0, 250, 200, 0])
plt.grid(True, lw=3, color="black")
plt.xticks(np.arange(11)*25,  np.arange(11)*4. )
plt.yticks(np.arange(11)*20,  np.arange(11)*25. )
plt.ylabel('Time (ns)')
plt.xlabel('Survey location (m)')
fig.savefig('ubc_GPRdata_coord.png')
plt.show()

# %%
vair*20*1e-9*0.5
# Out:
# 0.94802699262036716
