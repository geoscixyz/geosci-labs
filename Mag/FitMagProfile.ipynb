# %%
from importMag import *
# %matplotlib inline

# %% [markdown]
# Need some descriptions here:

# %%
diameter = 1.4e-2
length = 3. 
prism = ViewPrism(diameter, length, diameter, 0.5)
display(prism)
# Out:
# True

# %% [markdown]
# - add entry boxes for earth's magnetic field params
# - susc range too large?
# - give list of parameters,

# %%
Q1 = fitlineRem()
display(Q1)
# Out:
# True
