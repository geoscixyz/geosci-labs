# %%
from importMag import *
# %matplotlib inline

# %% [markdown]
# Need some descriptions here:

# %%
prism = ViewPrism(1., 5., 1., 3)
display(prism)
# Out:
# True

# %% [markdown]
# - add entry boxes for earth's magnetic field params
# - susc range too large?
# - change x-axis range (our line starts at 5m)

# %%
Q1 = fitlineInd()
display(Q1)
# Out:
# True

# %%
Q2 = fitlineRem(Q1.kwargs["x0"], Q1.kwargs["depth"], Q1.kwargs["susc"])
display(Q2)
# Out:
# True
