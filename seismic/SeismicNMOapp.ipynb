# %% [markdown]
# # Using the Notebook

# %% [markdown]
# This is the <a href="http://ipython.org/notebook.html">iPython Notebook</a>, an interactive coding and computation environment. For this lab, you do not have to write any code, you will only be running it.
#
# To use the notebook:
# - "Shift + Enter" runs the code within the cell (so does the forward arrow button near the top of the document)
# - You can alter variables and re-run cells
# - If you want to start with a clean slate, restart the Kernel either by going to the top, clicking on Kernel: Restart, or by "esc + 00" (if you do this, you will need to re-run Step 0 before running any other cells in the notebook)
#
# Instructions as to how to set up Python and the iPython notebook on your personal computer are attached in the appendix of the lab

# %% [markdown]
# ## Step 0: Import Necessary Packages

# %%
# %pylab inline
from SeisWidgetImport import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Two common-mid-point (CMP) gathers: Clean and Noisy

# %% [markdown]
# We have two CMP gathers generated from different geologic models. One data set is clean and the other is contaminated with noise. The seismic data were adapted from SeismicLab (http://seismic-lab.physics.ualberta.ca/).
#
# In this notebook, we will walk through how to construct a normal incidence seismogram from these data sets.
#
# We will do this in the following steps:
# - Step 1: Plot the data
# - Step 2: Fit a hyperbola to the data
# - Step 3: NMO correction and Stack

# %% [markdown]
# ## Step 1: Plot the data

# %% [markdown]
# As you can see from clean CMP gather, you can recognize that we have only have one reflector, meaning there is a single interface seperating two geologic units visible in these data.
# (Note: The direct and any refracted arrivals have been removed).
#
# It is difficult to distinguish any reflectors in the noisy data. However, there is a single reflector in these data, and we will perform normal moveout (NMO) and stacking operations to construct a normal-incidence seismogram where this reflector is visible.
#
# Noisy CMP  gather is in the same set-up where we only have one reflector. This directly indicates that we can distinguish one layer boundary through these data sets (so, we have two layers). We can estimate some unknown properties from these data sets: velocities of first and second layer, and thickness of the first layer.

# %%
# Plot the data
ViewWiggle(syndata, obsdata)

# %% [markdown]
# ### Step 2: Fit A Hyperbola to the Data

# %% [markdown]
# a. Assume that each reflection event in a CMP gather has a travel time that corresponds to a hyperbola:

# %% [markdown]
# ### $$ t(x) = \sqrt{\frac{x^2}{v^2_{stacking}} + t_0^2}$$

# %% [markdown]
# where $x$ is offset between source and receiver, $v_{stacking}$ is stacking velocity, and $t_0$ is the intercept time:

# %% [markdown]
# ### $$ t_0 = \sqrt{\frac{4d^2}{v^2_{stacking}}}$$

# %% [markdown]
# where $d$ is the thickness of the fisrt layer.

# %% [markdown]
# b. For each reflection event hyperbola, perform a velocity analysis to find $v_{stacking}$. This is done by first choosing $t_o$. Then choose a trial value of velocity.

# %% [markdown]
# <img src="http://www.eos.ubc.ca/courses/eosc350/content/methods/meth_10d/assets/kearey_fig4_21.gif"></img>

# %% [markdown]
# c. Calculate the Normal Moveout Correction: Using the hyperbolia corresponding to $v_{stacking}$, compute the normal moveout for each trace and then adjust the reflection time by the amount $\triangle T$:

# %% [markdown]
# ### $$ \triangle T = t_0-t(x)$$

# %% [markdown]
# <img src="http://www.eos.ubc.ca/courses/eosc350/content/methods/meth_10d/assets/ch1_fig8.gif"></img>

# %% [markdown]
# Estimate $t_0$ and $v_{stack}$, then apply NMO correction (For clean CMP gather)

# %%
# Fit hyperbola to clean data
clean = interact(CleanNMOWidget, t0 = (0.2, 0.8, 0.01), v = (1000., 5000., 100.))

# %% [markdown]
# ### Step 2: Stack the NMO corrected Data $v_{stack}$ (For clean CMP gather)

# %% [markdown]
# Enter the

# %%
#Input estimated stacking velocity for clean CMP gahter and run below cell by pressing shift + enter
t0_clean     = 0.1
vstack_clean = 3500.
NMOstackSingle(syndata, vstack_clean)

# %% [markdown]
# ### Step2-4: Etimate $t_0$ and $v_{stack}$, then apply NMO correction (For noisy CMP gather)

# %% [markdown]
# Different from previous one, we have got pretty noisy CMP gather. So first, estimate one $t_0$, and three plausible $v_{stack}$ in this case. NMO correction is applied for $v_2$ in the widget.

# %%
noisy = interact(NoisyNMOWidget, tintercept = (0.1, 0.6, 0.01), v1 = (0., 1500., 100.), v2 = (1500., 3000., 100.), v3 = (3000., 4500., 100.))

# %% [markdown]
# ### Step5: Apply CMP stack with estimated $v_{stack}$ (For noisy CMP gather)

# %% [markdown]
# We chose three plausible $v_{stack}$'s. Put those values in the below cell.

# %%
vstack_noisy1 = 1800.
vstack_noisy2 = 2500.
vstack_noisy3 = 3500.

# %%
NMOstackthree(obsdata, vstack_noisy1, vstack_noisy2, vstack_noisy3)
