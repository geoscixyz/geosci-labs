# %%
# %pylab inline
from syntheticSeismogram import syntheticSeismogram
from IPython.display import set_matplotlib_formats
from IPython.html.widgets import *
set_matplotlib_formats('png')
matplotlib.rcParams['savefig.dpi'] = 100 # Change this to adjust figure size
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d      = [0., 50., 100.]       # Position of top of each layer (m)
v      = [350., 1000., 2000.]  # Velocity of each layer (m/s)
rho    = [1700., 2000., 2500.] # Density of each layer (kg/m^3)
wavtyp = 'RICKER'              # Wavelet type
wavf   = [100.]                # Wavelet Frequency
usingT = False                 # Use Transmission Coefficients?

# %%
syntheticSeismogram(v, rho, d, wavtyp, wavf, usingT)
# Out:
# /Users/lindseyheagy/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter:
# ho$
# ^
# Expected end of text (at char 0), (line:1, col:1)
#   FormatterWarning,
