# %%
# %pylab inline
import scipy.io
from EOSC350widget import NMOWidget, stack
from simpegseis import UtilsSeis
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png')
matplotlib.rcParams['savefig.dpi'] = 100 # Change this to adjust figure size
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dx = 20.
data = scipy.io.loadmat('SeismicLab/data_syn.mat')
syndata = data['D'].T[:, :280]
time = 0.004*np.arange(syndata.shape[1])
xorig = np.arange(38)*dx

# %%
import numpy as np

# %%
syndata_2 = data['D'].T[:, 280:]

# %%
obsdata = syndata + np.random.randn(syndata.shape[0], syndata.shape[1])*0*abs(syndata).mean()

# %%
UtilsSeis.wiggle(np.fliplr(syndata_2), scale=0.2)

# %% [markdown]
# # Normal Move Out (NMO) correction

# %% [markdown]
# ### $$ t(x) = \frac{x^2}{v^2} + t_0^2$$

# %% [markdown]
# ### $$ t_0 = \sqrt{\frac{4d^2}{v^2}}$$

# %%
from IPython.html.widgets import *
i = interact(NMOWidget, tintercept = (0., 1.2, 0.025), v = (500., 2500., 50.))

# %%
stack(obsdata, xorig, time, 0.475, 1500)

# %%
stack(obsdata, xorig, time, 0.475, 1200)

# %%
stack(obsdata, xorig, time, 0.475, 1050)
